# %%
import requests

# %%
try:
    import io
    from io import BytesIO
    import pandas as pd
    from google.cloud import storage
    import os
    
except Exception as e:
    print("Some Modules are Missing{}".format(e))

# %%
pip install --upgrade google-cloud-storage
# Out:
# Requirement already up-to-date: google-cloud-storage in c:\users\jaleel.jenkins\anaconda3\lib\site-packages (1.39.0)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#Los Angeles, CA
url = "https://community-open-weather-map.p.rapidapi.com/forecast"

querystring = {"q":"Los Angeles,us"}

headers = {
    'x-rapidapi-key': "f0c8655d3emshdb6f614945745f8p18a098jsn52d71ac7d9a2",
    'x-rapidapi-host': "community-open-weather-map.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"cod":"200","message":0,"cnt":40,"list":[{"dt":1624870800,"main":{"temp":291.66,"feels_like":291.76,"temp_min":291.66,"temp_max":294.62,"pressure":1006,"sea_level":1006,"grnd_level":995,"humidity":84,"temp_kf":-2.96},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04n"}],"clouds":{"all":75},"wind":{"speed":1.89,"deg":175,"gust":1.92},"visibility":10000,"pop":0,"sys":{"pod":"n"},"dt_txt":"2021-06-28 09:00:00"},{"dt":1624881600,"main":{"temp":292.49,"feels_like":292.54,"temp_min":292.49,"temp_max":294.14,"pressure":1006,"sea_level":1006,"grnd_level":995,"humidity":79,"temp_kf":-1.65},"weather":[{"id":802,"main":"Clouds","description":"scattered clouds","icon":"03n"}],"clouds":{"all":50},"wind":{"speed":1.2,"deg":187,"gust":1.35},"visibility":10000,"pop":0,"sys":{"pod":"n"},"dt_txt":"2021-06-28 12:00:00"},{"dt":1624892400,"main":{"temp":295.13,"feels_like":295.13,"temp_min":295.13,"temp_max":296.86,"pressure":1006,"sea_level":1006,"grnd_level":996,"humidity":
# ...

# %%
import json
import pandas as pd

# %%
data = response.json()

# %%
data
# Out:
# {'cod': '200',
#  'message': 0,
#  'cnt': 40,
#  'list': [{'dt': 1624870800,
#    'main': {'temp': 291.66,
#     'feels_like': 291.76,
#     'temp_min': 291.66,
#     'temp_max': 294.62,
#     'pressure': 1006,
#     'sea_level': 1006,
#     'grnd_level': 995,
#     'humidity': 84,
#     'temp_kf': -2.96},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 75},
#    'wind': {'speed': 1.89, 'deg': 175, 'gust': 1.92},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2021-06-28 09:00:00'},
#   {'dt': 1624881600,
#    'main': {'temp': 292.49,
#     'feels_like': 292.54,
#     'temp_min': 292.49,
#     'temp_max': 294.14,
#     'pressure': 1006,
#     'sea_level': 1006,
#     'grnd_level': 995,
#     'humidity': 79,
#     'temp_kf': -1.65},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
# ...

# %%
#Parse JSON data from nested lists
h=[]
for i in data['list']: 
    h.append(i)
    
weather_df = pd.DataFrame(h)

# %%
weather_df.head()
# Out:
#            dt                                               main  \
# 0  1624870800  {'temp': 291.66, 'feels_like': 291.76, 'temp_m...
# 1  1624881600  {'temp': 292.49, 'feels_like': 292.54, 'temp_m...
# 2  1624892400  {'temp': 295.13, 'feels_like': 295.13, 'temp_m...
# 3  1624903200  {'temp': 303.09, 'feels_like': 302.66, 'temp_m...
# 4  1624914000  {'temp': 303.15, 'feels_like': 302.96, 'temp_m...
#
#                                              weather       clouds  \
# 0  [{'id': 803, 'main': 'Clouds', 'description': ...  {'all': 75}
# 1  [{'id': 802, 'main': 'Clouds', 'description': ...  {'all': 50}
# 2  [{'id': 802, 'main': 'Clouds', 'description': ...  {'all': 25}
# 3  [{'id': 800, 'main': 'Clear', 'description': '...   {'all': 0}
# 4  [{'id': 800, 'main': 'Clear', 'description': '...   {'all': 1}
#
#                                         wind  visibility  pop           sys  \
# 0  {'speed': 1.89, 'deg': 175, 'gust': 1.92}       10000  0.0  {'pod': 'n'}
# ...

# %%
len(h)
# Out:
# 40

# %%
weather_df.dtypes
# Out:
# dt              int64
# main           object
# weather        object
# clouds         object
# wind           object
# visibility      int64
# pop           float64
# sys            object
# dt_txt         object
# dtype: object

# %%
mod_df = weather_df.loc[:,['dt','main', 'weather', 'clouds', 'wind', 'visibility', 'pop', 'sys', 'dt_txt']]
mod_df = mod_df.explode('weather').head()

# %%
weather_data = pd.json_normalize(json.loads(mod_df.\
                                       to_json(orient="records")))
weather_data
# Out:
#            dt  visibility  pop               dt_txt  main.temp  \
# 0  1624870800       10000  0.0  2021-06-28 09:00:00     291.66
# 1  1624881600       10000  0.0  2021-06-28 12:00:00     292.49
# 2  1624892400       10000  0.0  2021-06-28 15:00:00     295.13
# 3  1624903200       10000  0.0  2021-06-28 18:00:00     303.09
# 4  1624914000       10000  0.0  2021-06-28 21:00:00     303.15
#
#    main.feels_like  main.temp_min  main.temp_max  main.pressure  \
# 0           291.76         291.66         294.62           1006
# 1           292.54         292.49         294.14           1006
# 2           295.13         295.13         296.86           1006
# 3           302.66         303.09         303.09           1005
# 4           302.96         303.15         303.15           1004
#
#    main.sea_level  ...  main.temp_kf  weather.id  weather.main  \
# 0            1006  ...         -2.96         803        Clouds
# 1            1006  ...         -1.65         802        Clouds
# ...

# %%
weather_data.columns = ['dt', 'visibility', 'pop', 'date', 'temp', 'feels_like', 'temp_min', 'temp_max', 'pressure', 'sea_level', 'grnd_level', 'humidity', 'temp_kf', 'weather_id', 'weather_main', 'weather_description', 'weather_icon', 'clouds_all', 'wind_speed', 'wind_deg', 'wind_gust', 'sys_pod']

# %%
weather_data
# Out:
#            dt  visibility   pop                 date  rain    temp  \
# 0  1624870800       10000  0.18  2021-06-28 09:00:00   NaN  296.40
# 1  1624881600       10000  0.14  2021-06-28 12:00:00   NaN  296.10
# 2  1624892400       10000  0.41  2021-06-28 15:00:00   NaN  298.46
# 3  1624903200       10000  0.70  2021-06-28 18:00:00   NaN  302.22
# 4  1624914000       10000  0.96  2021-06-28 21:00:00   NaN  301.66
#
#    feels_like  temp_min  temp_max  pressure  ...  weather_id  weather_main  \
# 0      297.21    294.87    296.40      1019  ...         800         Clear
# 1      296.80    295.51    296.10      1019  ...         800         Clear
# 2      299.06    298.46    299.49      1020  ...         500          Rain
# 3      305.13    302.22    302.22      1020  ...         500          Rain
# 4      305.00    301.66    301.66      1019  ...         500          Rain
#
#    weather_description  weather_icon  clouds_all wind_speed wind_deg  \
# ...

# %%
weather_data.to_csv(r'C:\Users\Jaleel.Jenkins\Desktop\StockX\weather_data_Los_Angeles.csv', index=False)

# %%
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "clear-zenith-316501-cff3f97b0e20.json"

# %%
storage_client = storage.Client.from_service_account_json(r'C:\Users\Jaleel.Jenkins\Desktop\StockX\clear-zenith-316501-cff3f97b0e20.json')

# %%
bucket = storage_client.get_bucket("data_bucket_jj")

# %%
filename = "%s/%s" % ('',r'C:\Users\Jaleel.Jenkins\Desktop\StockX\weather_data_Los_Angeles.csv')
blob = bucket.blob(filename)
blob.upload_from_filename(r'C:\Users\Jaleel.Jenkins\Desktop\StockX\weather_data_Los_Angeles.csv')
